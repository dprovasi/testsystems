# %%
import pyemma
pyemma.__version__
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pyemma.coordinates as coor

# %%
topfile = './backbone.pdb'

# %%
from glob import glob
traj_list = ['./backbone-%d.dcd'%i for i in range(159)]

# %%
def splitbox(trajs, box,cutoff=100):
    original_lenghts = [len(traj) for traj in trajs]
    original_number = len(trajs)
    original_desc = ( np.array(original_lenghts).sum(), original_number)
    print("Original: %d frames in %d trajectories"% original_desc)
    trajs2=[]
    for traj in trajs:
        diff = traj[1:] - traj[:-1]
        bkpts = np.where(abs(diff)>=box)[0]
        bkpts = np.concatenate([
           np.array([0]),
           bkpts+1,
           np.array([len(traj)])])
        for i,b in enumerate(bkpts[:-1]):
            if len(traj[b:bkpts[i+1]])>cutoff:
                 trajs2.append(traj[b:bkpts[i+1]])
    new_lenghts = [len(traj) for traj in trajs2]
    new_number = len(trajs2)
    new_desc = ( np.array(new_lenghts).sum(), new_number)
    print("New: %d frames in %d trajectories"% new_desc)
    return trajs2

# %%
split_traj = splitbox(traj_list,100)
# Out:
# Original: 2752 frames in 159 trajectories
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9921040ee4d6> in <module>()
# ----> 1 split_traj = splitbox(traj_list,100)
#
# <ipython-input-6-9c5f7a7876d4> in splitbox(trajs, box, cutoff)
#       6     trajs2=[]
#       7     for traj in trajs:
# ----> 8         diff = traj[1:] - traj[:-1]
#       9         bkpts = np.where(abs(diff)>=box)[0]
#      10         bkpts = np.concatenate([
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# distance between all atoms (including 1 Na+ and protein without H)
feat_Ca = coor.featurizer(topfile)
# just use all xyz-coordinates
#feat_Ca.add_all()
feat_Ca.add_distances([[ 0, 2310], [ 1, 2310], [ 2, 2310], [ 3, 2310], [ 4, 2310], [ 5, 2310], [ 6, 2310], [ 7, 2310], [ 8, 2310], [ 9, 2310], [ 10, 2310], [ 11, 2310], [ 12, 2310], [ 13, 2310], [ 14, 2310], [ 15, 2310], [ 16, 2310], [ 17, 2310], [ 18, 2310], [ 19, 2310], [ 20, 2310], [ 21, 2310], [ 22, 2310], [ 23, 2310], [ 24, 2310], [ 25, 2310], [ 26, 2310], [ 27, 2310], [ 28, 2310], [ 29, 2310], [ 30, 2310], [ 31, 2310], [ 32, 2310], [ 33, 2310], [ 34, 2310], [ 35, 2310], [ 36, 2310], [ 37, 2310], [ 38, 2310], [ 39, 2310], [ 40, 2310], [ 41, 2310], [ 42, 2310], [ 43, 2310], [ 44, 2310], [ 45, 2310], [ 46, 2310], [ 47, 2310], [ 48, 2310], [ 49, 2310], [ 50, 2310], [ 51, 2310], [ 52, 2310], [ 53, 2310], [ 54, 2310], [ 55, 2310], [ 56, 2310], [ 57, 2310], [ 58, 2310], [ 59, 2310], [ 60, 2310], [ 61, 2310], [ 62, 2310], [ 63, 2310], [ 64, 2310], [ 65, 2310], [ 66, 2310], [ 67, 2310], [ 68, 2310], [ 69, 2310], [ 70, 2310], [ 71, 2310], [ 72, 2310], [ 73, 2310], [ 74, 2310], [ 75, 2310], [ 76, 2310], [ 77, 2310], [ 78, 2310], [ 79, 2310], [ 80, 2310], [ 81, 2310], [ 82, 2310], [ 83, 2310], [ 84, 2310], [ 85, 2310], [ 86, 2310], [ 87, 2310], [ 88, 2310], [ 89, 2310], [ 90, 2310], [ 91, 2310], [ 92, 2310], [ 93, 2310], [ 94, 2310], [ 95, 2310], [ 96, 2310], [ 97, 2310], [ 98, 2310], [ 99, 2310], [ 100, 2310], [ 101, 2310], [ 102, 2310], [ 103, 2310], [ 104, 2310], [ 105, 2310], [ 106, 2310], [ 107, 2310], [ 108, 2310], [ 109, 2310], [ 110, 2310], [ 111, 2310], [ 112, 2310], [ 113, 2310], [ 114, 2310], [ 115, 2310], [ 116, 2310], [ 117, 2310], [ 118, 2310], [ 119, 2310], [ 120, 2310], [ 121, 2310], [ 122, 2310], [ 123, 2310], [ 124, 2310], [ 125, 2310], [ 126, 2310], [ 127, 2310], [ 128, 2310], [ 129, 2310], [ 130, 2310], [ 131, 2310], [ 132, 2310], [ 133, 2310], [ 134, 2310], [ 135, 2310], [ 136, 2310], [ 137, 2310], [ 138, 2310], [ 139, 2310], [ 140, 2310], [ 141, 2310], [ 142, 2310], [ 143, 2310], [ 144, 2310], [ 145, 2310], [ 146, 2310], [ 147, 2310], [ 148, 2310], [ 149, 2310], [ 150, 2310], [ 151, 2310], [ 152, 2310], [ 153, 2310], [ 154, 2310], [ 155, 2310], [ 156, 2310], [ 157, 2310], [ 158, 2310], [ 159, 2310], [ 160, 2310], [ 161, 2310], [ 162, 2310], [ 163, 2310], [ 164, 2310], [ 165, 2310], [ 166, 2310], [ 167, 2310], [ 168, 2310], [ 169, 2310], [ 170, 2310], [ 171, 2310], [ 172, 2310], [ 173, 2310], [ 174, 2310], [ 175, 2310], [ 176, 2310], [ 177, 2310], [ 178, 2310], [ 179, 2310], [ 180, 2310], [ 181, 2310], [ 182, 2310], [ 183, 2310], [ 184, 2310], [ 185, 2310], [ 186, 2310], [ 187, 2310], [ 188, 2310], [ 189, 2310], [ 190, 2310], [ 191, 2310], [ 192, 2310], [ 193, 2310], [ 194, 2310], [ 195, 2310], [ 196, 2310], [ 197, 2310], [ 198, 2310], [ 199, 2310], [ 200, 2310], [ 201, 2310], [ 202, 2310], [ 203, 2310], [ 204, 2310], [ 205, 2310], [ 206, 2310], [ 207, 2310], [ 208, 2310], [ 209, 2310], [ 210, 2310], [ 211, 2310], [ 212, 2310], [ 213, 2310], [ 214, 2310], [ 215, 2310], [ 216, 2310], [ 217, 2310], [ 218, 2310], [ 219, 2310], [ 220, 2310], [ 221, 2310], [ 222, 2310], [ 223, 2310], [ 224, 2310], [ 225, 2310], [ 226, 2310], [ 227, 2310], [ 228, 2310], [ 229, 2310], [ 230, 2310], [ 231, 2310], [ 232, 2310], [ 233, 2310], [ 234, 2310], [ 235, 2310], [ 236, 2310], [ 237, 2310], [ 238, 2310], [ 239, 2310], [ 240, 2310], [ 241, 2310], [ 242, 2310], [ 243, 2310], [ 244, 2310], [ 245, 2310], [ 246, 2310], [ 247, 2310], [ 248, 2310], [ 249, 2310], [ 250, 2310], [ 251, 2310], [ 252, 2310], [ 253, 2310], [ 254, 2310], [ 255, 2310], [ 256, 2310], [ 257, 2310], [ 258, 2310], [ 259, 2310], [ 260, 2310], [ 261, 2310], [ 262, 2310], [ 263, 2310], [ 264, 2310], [ 265, 2310], [ 266, 2310], [ 267, 2310], [ 268, 2310], [ 269, 2310], [ 270, 2310], [ 271, 2310], [ 272, 2310], [ 273, 2310], [ 274, 2310], [ 275, 2310], [ 276, 2310], [ 277, 2310], [ 278, 2310], [ 279, 2310], [ 280, 2310], [ 281, 2310], [ 282, 2310], [ 283, 2310], [ 284, 2310], [ 285, 2310], [ 286, 2310], [ 287, 2310], [ 288, 2310], [ 289, 2310], [ 290, 2310], [ 291, 2310], [ 292, 2310], [ 293, 2310], [ 294, 2310], [ 295, 2310], [ 296, 2310], [ 297, 2310], [ 298, 2310], [ 299, 2310], [ 300, 2310], [ 301, 2310], [ 302, 2310], [ 303, 2310], [ 304, 2310], [ 305, 2310], [ 306, 2310], [ 307, 2310], [ 308, 2310], [ 309, 2310], [ 310, 2310], [ 311, 2310], [ 312, 2310], [ 313, 2310], [ 314, 2310], [ 315, 2310], [ 316, 2310], [ 317, 2310], [ 318, 2310], [ 319, 2310], [ 320, 2310], [ 321, 2310], [ 322, 2310], [ 323, 2310], [ 324, 2310], [ 325, 2310], [ 326, 2310], [ 327, 2310], [ 328, 2310], [ 329, 2310], [ 330, 2310], [ 331, 2310], [ 332, 2310], [ 333, 2310], [ 334, 2310], [ 335, 2310], [ 336, 2310], [ 337, 2310], [ 338, 2310], [ 339, 2310], [ 340, 2310], [ 341, 2310], [ 342, 2310], [ 343, 2310], [ 344, 2310], [ 345, 2310], [ 346, 2310], [ 347, 2310], [ 348, 2310], [ 349, 2310], [ 350, 2310], [ 351, 2310], [ 352, 2310], [ 353, 2310], [ 354, 2310], [ 355, 2310], [ 356, 2310], [ 357, 2310], [ 358, 2310], [ 359, 2310], [ 360, 2310], [ 361, 2310], [ 362, 2310], [ 363, 2310], [ 364, 2310], [ 365, 2310], [ 366, 2310], [ 367, 2310], [ 368, 2310], [ 369, 2310], [ 370, 2310], [ 371, 2310], [ 372, 2310], [ 373, 2310], [ 374, 2310], [ 375, 2310], [ 376, 2310], [ 377, 2310], [ 378, 2310], [ 379, 2310], [ 380, 2310], [ 381, 2310], [ 382, 2310], [ 383, 2310], [ 384, 2310], [ 385, 2310], [ 386, 2310], [ 387, 2310], [ 388, 2310], [ 389, 2310], [ 390, 2310], [ 391, 2310], [ 392, 2310], [ 393, 2310], [ 394, 2310], [ 395, 2310], [ 396, 2310], [ 397, 2310], [ 398, 2310], [ 399, 2310], [ 400, 2310], [ 401, 2310], [ 402, 2310], [ 403, 2310], [ 404, 2310], [ 405, 2310], [ 406, 2310], [ 407, 2310], [ 408, 2310], [ 409, 2310], [ 410, 2310], [ 411, 2310], [ 412, 2310], [ 413, 2310], [ 414, 2310], [ 415, 2310], [ 416, 2310], [ 417, 2310], [ 418, 2310], [ 419, 2310], [ 420, 2310], [ 421, 2310], [ 422, 2310], [ 423, 2310], [ 424, 2310], [ 425, 2310], [ 426, 2310], [ 427, 2310], [ 428, 2310], [ 429, 2310], [ 430, 2310], [ 431, 2310], [ 432, 2310], [ 433, 2310], [ 434, 2310], [ 435, 2310], [ 436, 2310], [ 437, 2310], [ 438, 2310], [ 439, 2310], [ 440, 2310], [ 441, 2310], [ 442, 2310], [ 443, 2310], [ 444, 2310], [ 445, 2310], [ 446, 2310], [ 447, 2310], [ 448, 2310], [ 449, 2310], [ 450, 2310], [ 451, 2310], [ 452, 2310], [ 453, 2310], [ 454, 2310], [ 455, 2310], [ 456, 2310], [ 457, 2310], [ 458, 2310], [ 459, 2310], [ 460, 2310], [ 461, 2310], [ 462, 2310], [ 463, 2310], [ 464, 2310], [ 465, 2310], [ 466, 2310], [ 467, 2310], [ 468, 2310], [ 469, 2310], [ 470, 2310], [ 471, 2310], [ 472, 2310], [ 473, 2310], [ 474, 2310], [ 475, 2310], [ 476, 2310], [ 477, 2310], [ 478, 2310], [ 479, 2310], [ 480, 2310], [ 481, 2310], [ 482, 2310], [ 483, 2310], [ 484, 2310], [ 485, 2310], [ 486, 2310], [ 487, 2310], [ 488, 2310], [ 489, 2310], [ 490, 2310], [ 491, 2310], [ 492, 2310], [ 493, 2310], [ 494, 2310], [ 495, 2310], [ 496, 2310], [ 497, 2310], [ 498, 2310], [ 499, 2310], [ 500, 2310], [ 501, 2310], [ 502, 2310], [ 503, 2310], [ 504, 2310], [ 505, 2310], [ 506, 2310], [ 507, 2310], [ 508, 2310], [ 509, 2310], [ 510, 2310], [ 511, 2310], [ 512, 2310], [ 513, 2310], [ 514, 2310], [ 515, 2310], [ 516, 2310], [ 517, 2310], [ 518, 2310], [ 519, 2310], [ 520, 2310], [ 521, 2310], [ 522, 2310], [ 523, 2310], [ 524, 2310], [ 525, 2310], [ 526, 2310], [ 527, 2310], [ 528, 2310], [ 529, 2310], [ 530, 2310], [ 531, 2310], [ 532, 2310], [ 533, 2310], [ 534, 2310], [ 535, 2310], [ 536, 2310], [ 537, 2310], [ 538, 2310], [ 539, 2310], [ 540, 2310], [ 541, 2310], [ 542, 2310], [ 543, 2310], [ 544, 2310], [ 545, 2310], [ 546, 2310], [ 547, 2310], [ 548, 2310], [ 549, 2310], [ 550, 2310], [ 551, 2310], [ 552, 2310], [ 553, 2310], [ 554, 2310], [ 555, 2310], [ 556, 2310], [ 557, 2310], [ 558, 2310], [ 559, 2310], [ 560, 2310], [ 561, 2310], [ 562, 2310], [ 563, 2310], [ 564, 2310], [ 565, 2310], [ 566, 2310], [ 567, 2310], [ 568, 2310], [ 569, 2310], [ 570, 2310], [ 571, 2310], [ 572, 2310], [ 573, 2310], [ 574, 2310], [ 575, 2310], [ 576, 2310], [ 577, 2310], [ 578, 2310], [ 579, 2310], [ 580, 2310], [ 581, 2310], [ 582, 2310], [ 583, 2310], [ 584, 2310], [ 585, 2310], [ 586, 2310], [ 587, 2310], [ 588, 2310], [ 589, 2310], [ 590, 2310], [ 591, 2310], [ 592, 2310], [ 593, 2310], [ 594, 2310], [ 595, 2310], [ 596, 2310], [ 597, 2310], [ 598, 2310], [ 599, 2310], [ 600, 2310], [ 601, 2310], [ 602, 2310], [ 603, 2310], [ 604, 2310], [ 605, 2310], [ 606, 2310], [ 607, 2310], [ 608, 2310], [ 609, 2310], [ 610, 2310], [ 611, 2310], [ 612, 2310], [ 613, 2310], [ 614, 2310], [ 615, 2310], [ 616, 2310], [ 617, 2310], [ 618, 2310], [ 619, 2310], [ 620, 2310], [ 621, 2310], [ 622, 2310], [ 623, 2310], [ 624, 2310], [ 625, 2310], [ 626, 2310], [ 627, 2310], [ 628, 2310], [ 629, 2310], [ 630, 2310], [ 631, 2310], [ 632, 2310], [ 633, 2310], [ 634, 2310], [ 635, 2310], [ 636, 2310], [ 637, 2310], [ 638, 2310], [ 639, 2310], [ 640, 2310], [ 641, 2310], [ 642, 2310], [ 643, 2310], [ 644, 2310], [ 645, 2310], [ 646, 2310], [ 647, 2310], [ 648, 2310], [ 649, 2310], [ 650, 2310], [ 651, 2310], [ 652, 2310], [ 653, 2310], [ 654, 2310], [ 655, 2310], [ 656, 2310], [ 657, 2310], [ 658, 2310], [ 659, 2310], [ 660, 2310], [ 661, 2310], [ 662, 2310], [ 663, 2310], [ 664, 2310], [ 665, 2310], [ 666, 2310], [ 667, 2310], [ 668, 2310], [ 669, 2310], [ 670, 2310], [ 671, 2310], [ 672, 2310], [ 673, 2310], [ 674, 2310], [ 675, 2310], [ 676, 2310], [ 677, 2310], [ 678, 2310], [ 679, 2310], [ 680, 2310], [ 681, 2310], [ 682, 2310], [ 683, 2310], [ 684, 2310], [ 685, 2310], [ 686, 2310], [ 687, 2310], [ 688, 2310], [ 689, 2310], [ 690, 2310], [ 691, 2310], [ 692, 2310], [ 693, 2310], [ 694, 2310], [ 695, 2310], [ 696, 2310], [ 697, 2310], [ 698, 2310], [ 699, 2310], [ 700, 2310], [ 701, 2310], [ 702, 2310], [ 703, 2310], [ 704, 2310], [ 705, 2310], [ 706, 2310], [ 707, 2310], [ 708, 2310], [ 709, 2310], [ 710, 2310], [ 711, 2310], [ 712, 2310], [ 713, 2310], [ 714, 2310], [ 715, 2310], [ 716, 2310], [ 717, 2310], [ 718, 2310], [ 719, 2310], [ 720, 2310], [ 721, 2310], [ 722, 2310], [ 723, 2310], [ 724, 2310], [ 725, 2310], [ 726, 2310], [ 727, 2310], [ 728, 2310], [ 729, 2310], [ 730, 2310], [ 731, 2310], [ 732, 2310], [ 733, 2310], [ 734, 2310], [ 735, 2310], [ 736, 2310], [ 737, 2310], [ 738, 2310], [ 739, 2310], [ 740, 2310], [ 741, 2310], [ 742, 2310], [ 743, 2310], [ 744, 2310], [ 745, 2310], [ 746, 2310], [ 747, 2310], [ 748, 2310], [ 749, 2310], [ 750, 2310], [ 751, 2310], [ 752, 2310], [ 753, 2310], [ 754, 2310], [ 755, 2310], [ 756, 2310], [ 757, 2310], [ 758, 2310], [ 759, 2310], [ 760, 2310], [ 761, 2310], [ 762, 2310], [ 763, 2310], [ 764, 2310], [ 765, 2310], [ 766, 2310], [ 767, 2310], [ 768, 2310], [ 769, 2310], [ 770, 2310], [ 771, 2310], [ 772, 2310], [ 773, 2310], [ 774, 2310], [ 775, 2310], [ 776, 2310], [ 777, 2310], [ 778, 2310], [ 779, 2310], [ 780, 2310], [ 781, 2310], [ 782, 2310], [ 783, 2310], [ 784, 2310], [ 785, 2310], [ 786, 2310], [ 787, 2310], [ 788, 2310], [ 789, 2310], [ 790, 2310], [ 791, 2310], [ 792, 2310], [ 793, 2310], [ 794, 2310], [ 795, 2310], [ 796, 2310], [ 797, 2310], [ 798, 2310], [ 799, 2310], [ 800, 2310], [ 801, 2310], [ 802, 2310], [ 803, 2310], [ 804, 2310], [ 805, 2310], [ 806, 2310], [ 807, 2310], [ 808, 2310], [ 809, 2310], [ 810, 2310], [ 811, 2310], [ 812, 2310], [ 813, 2310], [ 814, 2310], [ 815, 2310], [ 816, 2310], [ 817, 2310], [ 818, 2310], [ 819, 2310], [ 820, 2310], [ 821, 2310], [ 822, 2310], [ 823, 2310], [ 824, 2310], [ 825, 2310], [ 826, 2310], [ 827, 2310], [ 828, 2310], [ 829, 2310], [ 830, 2310], [ 831, 2310], [ 832, 2310], [ 833, 2310], [ 834, 2310], [ 835, 2310], [ 836, 2310], [ 837, 2310], [ 838, 2310], [ 839, 2310], [ 840, 2310], [ 841, 2310], [ 842, 2310], [ 843, 2310], [ 844, 2310], [ 845, 2310], [ 846, 2310], [ 847, 2310], [ 848, 2310], [ 849, 2310], [ 850, 2310], [ 851, 2310], [ 852, 2310], [ 853, 2310], [ 854, 2310], [ 855, 2310], [ 856, 2310], [ 857, 2310], [ 858, 2310], [ 859, 2310], [ 860, 2310], [ 861, 2310], [ 862, 2310], [ 863, 2310], [ 864, 2310], [ 865, 2310], [ 866, 2310], [ 867, 2310], [ 868, 2310], [ 869, 2310], [ 870, 2310], [ 871, 2310], [ 872, 2310], [ 873, 2310], [ 874, 2310], [ 875, 2310], [ 876, 2310], [ 877, 2310], [ 878, 2310], [ 879, 2310], [ 880, 2310], [ 881, 2310], [ 882, 2310], [ 883, 2310], [ 884, 2310], [ 885, 2310], [ 886, 2310], [ 887, 2310], [ 888, 2310], [ 889, 2310], [ 890, 2310], [ 891, 2310], [ 892, 2310], [ 893, 2310], [ 894, 2310], [ 895, 2310], [ 896, 2310], [ 897, 2310], [ 898, 2310], [ 899, 2310], [ 900, 2310], [ 901, 2310], [ 902, 2310], [ 903, 2310], [ 904, 2310], [ 905, 2310], [ 906, 2310], [ 907, 2310], [ 908, 2310], [ 909, 2310], [ 910, 2310], [ 911, 2310], [ 912, 2310], [ 913, 2310], [ 914, 2310], [ 915, 2310], [ 916, 2310], [ 917, 2310], [ 918, 2310], [ 919, 2310], [ 920, 2310], [ 921, 2310], [ 922, 2310], [ 923, 2310], [ 924, 2310], [ 925, 2310], [ 926, 2310], [ 927, 2310], [ 928, 2310], [ 929, 2310], [ 930, 2310], [ 931, 2310], [ 932, 2310], [ 933, 2310], [ 934, 2310], [ 935, 2310], [ 936, 2310], [ 937, 2310], [ 938, 2310], [ 939, 2310], [ 940, 2310], [ 941, 2310], [ 942, 2310], [ 943, 2310], [ 944, 2310], [ 945, 2310], [ 946, 2310], [ 947, 2310], [ 948, 2310], [ 949, 2310], [ 950, 2310], [ 951, 2310], [ 952, 2310], [ 953, 2310], [ 954, 2310], [ 955, 2310], [ 956, 2310], [ 957, 2310], [ 958, 2310], [ 959, 2310], [ 960, 2310], [ 961, 2310], [ 962, 2310], [ 963, 2310], [ 964, 2310], [ 965, 2310], [ 966, 2310], [ 967, 2310], [ 968, 2310], [ 969, 2310], [ 970, 2310], [ 971, 2310], [ 972, 2310], [ 973, 2310], [ 974, 2310], [ 975, 2310], [ 976, 2310], [ 977, 2310], [ 978, 2310], [ 979, 2310], [ 980, 2310], [ 981, 2310], [ 982, 2310], [ 983, 2310], [ 984, 2310], [ 985, 2310], [ 986, 2310], [ 987, 2310], [ 988, 2310], [ 989, 2310], [ 990, 2310], [ 991, 2310], [ 992, 2310], [ 993, 2310], [ 994, 2310], [ 995, 2310], [ 996, 2310], [ 997, 2310], [ 998, 2310], [ 999, 2310], [ 1000, 2310], [ 1001, 2310], [ 1002, 2310], [ 1003, 2310], [ 1004, 2310], [ 1005, 2310], [ 1006, 2310], [ 1007, 2310], [ 1008, 2310], [ 1009, 2310], [ 1010, 2310], [ 1011, 2310], [ 1012, 2310], [ 1013, 2310], [ 1014, 2310], [ 1015, 2310], [ 1016, 2310], [ 1017, 2310], [ 1018, 2310], [ 1019, 2310], [ 1020, 2310], [ 1021, 2310], [ 1022, 2310], [ 1023, 2310], [ 1024, 2310], [ 1025, 2310], [ 1026, 2310], [ 1027, 2310], [ 1028, 2310], [ 1029, 2310], [ 1030, 2310], [ 1031, 2310], [ 1032, 2310], [ 1033, 2310], [ 1034, 2310], [ 1035, 2310], [ 1036, 2310], [ 1037, 2310], [ 1038, 2310], [ 1039, 2310], [ 1040, 2310], [ 1041, 2310], [ 1042, 2310], [ 1043, 2310], [ 1044, 2310], [ 1045, 2310], [ 1046, 2310], [ 1047, 2310], [ 1048, 2310], [ 1049, 2310], [ 1050, 2310], [ 1051, 2310], [ 1052, 2310], [ 1053, 2310], [ 1054, 2310], [ 1055, 2310], [ 1056, 2310], [ 1057, 2310], [ 1058, 2310], [ 1059, 2310], [ 1060, 2310], [ 1061, 2310], [ 1062, 2310], [ 1063, 2310], [ 1064, 2310], [ 1065, 2310], [ 1066, 2310], [ 1067, 2310], [ 1068, 2310], [ 1069, 2310], [ 1070, 2310], [ 1071, 2310], [ 1072, 2310], [ 1073, 2310], [ 1074, 2310], [ 1075, 2310], [ 1076, 2310], [ 1077, 2310], [ 1078, 2310], [ 1079, 2310], [ 1080, 2310], [ 1081, 2310], [ 1082, 2310], [ 1083, 2310], [ 1084, 2310], [ 1085, 2310], [ 1086, 2310], [ 1087, 2310], [ 1088, 2310], [ 1089, 2310], [ 1090, 2310], [ 1091, 2310], [ 1092, 2310], [ 1093, 2310], [ 1094, 2310], [ 1095, 2310], [ 1096, 2310], [ 1097, 2310], [ 1098, 2310], [ 1099, 2310], [ 1100, 2310], [ 1101, 2310], [ 1102, 2310], [ 1103, 2310], [ 1104, 2310], [ 1105, 2310], [ 1106, 2310], [ 1107, 2310], [ 1108, 2310], [ 1109, 2310], [ 1110, 2310], [ 1111, 2310], [ 1112, 2310], [ 1113, 2310], [ 1114, 2310], [ 1115, 2310], [ 1116, 2310], [ 1117, 2310], [ 1118, 2310], [ 1119, 2310], [ 1120, 2310], [ 1121, 2310], [ 1122, 2310], [ 1123, 2310], [ 1124, 2310], [ 1125, 2310], [ 1126, 2310], [ 1127, 2310], [ 1128, 2310], [ 1129, 2310], [ 1130, 2310], [ 1131, 2310], [ 1132, 2310], [ 1133, 2310], [ 1134, 2310], [ 1135, 2310], [ 1136, 2310], [ 1137, 2310], [ 1138, 2310], [ 1139, 2310], [ 1140, 2310], [ 1141, 2310], [ 1142, 2310], [ 1143, 2310], [ 1144, 2310], [ 1145, 2310], [ 1146, 2310], [ 1147, 2310], [ 1148, 2310], [ 1149, 2310], [ 1150, 2310], [ 1151, 2310], [ 1152, 2310], [ 1153, 2310], [ 1154, 2310], [ 1155, 2310], [ 1156, 2310], [ 1157, 2310], [ 1158, 2310], [ 1159, 2310], [ 1160, 2310], [ 1161, 2310], [ 1162, 2310], [ 1163, 2310], [ 1164, 2310], [ 1165, 2310], [ 1166, 2310], [ 1167, 2310], [ 1168, 2310], [ 1169, 2310], [ 1170, 2310], [ 1171, 2310], [ 1172, 2310], [ 1173, 2310], [ 1174, 2310], [ 1175, 2310], [ 1176, 2310], [ 1177, 2310], [ 1178, 2310], [ 1179, 2310], [ 1180, 2310], [ 1181, 2310], [ 1182, 2310], [ 1183, 2310], [ 1184, 2310], [ 1185, 2310], [ 1186, 2310], [ 1187, 2310], [ 1188, 2310], [ 1189, 2310], [ 1190, 2310], [ 1191, 2310], [ 1192, 2310], [ 1193, 2310], [ 1194, 2310], [ 1195, 2310], [ 1196, 2310], [ 1197, 2310], [ 1198, 2310], [ 1199, 2310], [ 1200, 2310], [ 1201, 2310], [ 1202, 2310], [ 1203, 2310], [ 1204, 2310], [ 1205, 2310], [ 1206, 2310], [ 1207, 2310], [ 1208, 2310], [ 1209, 2310], [ 1210, 2310], [ 1211, 2310], [ 1212, 2310], [ 1213, 2310], [ 1214, 2310], [ 1215, 2310], [ 1216, 2310], [ 1217, 2310], [ 1218, 2310], [ 1219, 2310], [ 1220, 2310], [ 1221, 2310], [ 1222, 2310], [ 1223, 2310], [ 1224, 2310], [ 1225, 2310], [ 1226, 2310], [ 1227, 2310], [ 1228, 2310], [ 1229, 2310], [ 1230, 2310], [ 1231, 2310], [ 1232, 2310], [ 1233, 2310], [ 1234, 2310], [ 1235, 2310], [ 1236, 2310], [ 1237, 2310], [ 1238, 2310], [ 1239, 2310], [ 1240, 2310], [ 1241, 2310], [ 1242, 2310], [ 1243, 2310], [ 1244, 2310], [ 1245, 2310], [ 1246, 2310], [ 1247, 2310], [ 1248, 2310], [ 1249, 2310], [ 1250, 2310], [ 1251, 2310], [ 1252, 2310], [ 1253, 2310], [ 1254, 2310], [ 1255, 2310], [ 1256, 2310], [ 1257, 2310], [ 1258, 2310], [ 1259, 2310], [ 1260, 2310], [ 1261, 2310], [ 1262, 2310], [ 1263, 2310], [ 1264, 2310], [ 1265, 2310], [ 1266, 2310], [ 1267, 2310], [ 1268, 2310], [ 1269, 2310], [ 1270, 2310], [ 1271, 2310], [ 1272, 2310], [ 1273, 2310], [ 1274, 2310], [ 1275, 2310], [ 1276, 2310], [ 1277, 2310], [ 1278, 2310], [ 1279, 2310], [ 1280, 2310], [ 1281, 2310], [ 1282, 2310], [ 1283, 2310], [ 1284, 2310], [ 1285, 2310], [ 1286, 2310], [ 1287, 2310], [ 1288, 2310], [ 1289, 2310], [ 1290, 2310], [ 1291, 2310], [ 1292, 2310], [ 1293, 2310], [ 1294, 2310], [ 1295, 2310], [ 1296, 2310], [ 1297, 2310], [ 1298, 2310], [ 1299, 2310], [ 1300, 2310], [ 1301, 2310], [ 1302, 2310], [ 1303, 2310], [ 1304, 2310], [ 1305, 2310], [ 1306, 2310], [ 1307, 2310], [ 1308, 2310], [ 1309, 2310], [ 1310, 2310], [ 1311, 2310], [ 1312, 2310], [ 1313, 2310], [ 1314, 2310], [ 1315, 2310], [ 1316, 2310], [ 1317, 2310], [ 1318, 2310], [ 1319, 2310], [ 1320, 2310], [ 1321, 2310], [ 1322, 2310], [ 1323, 2310], [ 1324, 2310], [ 1325, 2310], [ 1326, 2310], [ 1327, 2310], [ 1328, 2310], [ 1329, 2310], [ 1330, 2310], [ 1331, 2310], [ 1332, 2310], [ 1333, 2310], [ 1334, 2310], [ 1335, 2310], [ 1336, 2310], [ 1337, 2310], [ 1338, 2310], [ 1339, 2310], [ 1340, 2310], [ 1341, 2310], [ 1342, 2310], [ 1343, 2310], [ 1344, 2310], [ 1345, 2310], [ 1346, 2310], [ 1347, 2310], [ 1348, 2310], [ 1349, 2310], [ 1350, 2310], [ 1351, 2310], [ 1352, 2310], [ 1353, 2310], [ 1354, 2310], [ 1355, 2310], [ 1356, 2310], [ 1357, 2310], [ 1358, 2310], [ 1359, 2310], [ 1360, 2310], [ 1361, 2310], [ 1362, 2310], [ 1363, 2310], [ 1364, 2310], [ 1365, 2310], [ 1366, 2310], [ 1367, 2310], [ 1368, 2310], [ 1369, 2310], [ 1370, 2310], [ 1371, 2310], [ 1372, 2310], [ 1373, 2310], [ 1374, 2310], [ 1375, 2310], [ 1376, 2310], [ 1377, 2310], [ 1378, 2310], [ 1379, 2310], [ 1380, 2310], [ 1381, 2310], [ 1382, 2310], [ 1383, 2310], [ 1384, 2310], [ 1385, 2310], [ 1386, 2310], [ 1387, 2310], [ 1388, 2310], [ 1389, 2310], [ 1390, 2310], [ 1391, 2310], [ 1392, 2310], [ 1393, 2310], [ 1394, 2310], [ 1395, 2310], [ 1396, 2310], [ 1397, 2310], [ 1398, 2310], [ 1399, 2310], [ 1400, 2310], [ 1401, 2310], [ 1402, 2310], [ 1403, 2310], [ 1404, 2310], [ 1405, 2310], [ 1406, 2310], [ 1407, 2310], [ 1408, 2310], [ 1409, 2310], [ 1410, 2310], [ 1411, 2310], [ 1412, 2310], [ 1413, 2310], [ 1414, 2310], [ 1415, 2310], [ 1416, 2310], [ 1417, 2310], [ 1418, 2310], [ 1419, 2310], [ 1420, 2310], [ 1421, 2310], [ 1422, 2310], [ 1423, 2310], [ 1424, 2310], [ 1425, 2310], [ 1426, 2310], [ 1427, 2310], [ 1428, 2310], [ 1429, 2310], [ 1430, 2310], [ 1431, 2310], [ 1432, 2310], [ 1433, 2310], [ 1434, 2310], [ 1435, 2310], [ 1436, 2310], [ 1437, 2310], [ 1438, 2310], [ 1439, 2310], [ 1440, 2310], [ 1441, 2310], [ 1442, 2310], [ 1443, 2310], [ 1444, 2310], [ 1445, 2310], [ 1446, 2310], [ 1447, 2310], [ 1448, 2310], [ 1449, 2310], [ 1450, 2310], [ 1451, 2310], [ 1452, 2310], [ 1453, 2310], [ 1454, 2310], [ 1455, 2310], [ 1456, 2310], [ 1457, 2310], [ 1458, 2310], [ 1459, 2310], [ 1460, 2310], [ 1461, 2310], [ 1462, 2310], [ 1463, 2310], [ 1464, 2310], [ 1465, 2310], [ 1466, 2310], [ 1467, 2310], [ 1468, 2310], [ 1469, 2310], [ 1470, 2310], [ 1471, 2310], [ 1472, 2310], [ 1473, 2310], [ 1474, 2310], [ 1475, 2310], [ 1476, 2310], [ 1477, 2310], [ 1478, 2310], [ 1479, 2310], [ 1480, 2310], [ 1481, 2310], [ 1482, 2310], [ 1483, 2310], [ 1484, 2310], [ 1485, 2310], [ 1486, 2310], [ 1487, 2310], [ 1488, 2310], [ 1489, 2310], [ 1490, 2310], [ 1491, 2310], [ 1492, 2310], [ 1493, 2310], [ 1494, 2310], [ 1495, 2310], [ 1496, 2310], [ 1497, 2310], [ 1498, 2310], [ 1499, 2310], [ 1500, 2310], [ 1501, 2310], [ 1502, 2310], [ 1503, 2310], [ 1504, 2310], [ 1505, 2310], [ 1506, 2310], [ 1507, 2310], [ 1508, 2310], [ 1509, 2310], [ 1510, 2310], [ 1511, 2310], [ 1512, 2310], [ 1513, 2310], [ 1514, 2310], [ 1515, 2310], [ 1516, 2310], [ 1517, 2310], [ 1518, 2310], [ 1519, 2310], [ 1520, 2310], [ 1521, 2310], [ 1522, 2310], [ 1523, 2310], [ 1524, 2310], [ 1525, 2310], [ 1526, 2310], [ 1527, 2310], [ 1528, 2310], [ 1529, 2310], [ 1530, 2310], [ 1531, 2310], [ 1532, 2310], [ 1533, 2310], [ 1534, 2310], [ 1535, 2310], [ 1536, 2310], [ 1537, 2310], [ 1538, 2310], [ 1539, 2310], [ 1540, 2310], [ 1541, 2310], [ 1542, 2310], [ 1543, 2310], [ 1544, 2310], [ 1545, 2310], [ 1546, 2310], [ 1547, 2310], [ 1548, 2310], [ 1549, 2310], [ 1550, 2310], [ 1551, 2310], [ 1552, 2310], [ 1553, 2310], [ 1554, 2310], [ 1555, 2310], [ 1556, 2310], [ 1557, 2310], [ 1558, 2310], [ 1559, 2310], [ 1560, 2310], [ 1561, 2310], [ 1562, 2310], [ 1563, 2310], [ 1564, 2310], [ 1565, 2310], [ 1566, 2310], [ 1567, 2310], [ 1568, 2310], [ 1569, 2310], [ 1570, 2310], [ 1571, 2310], [ 1572, 2310], [ 1573, 2310], [ 1574, 2310], [ 1575, 2310], [ 1576, 2310], [ 1577, 2310], [ 1578, 2310], [ 1579, 2310], [ 1580, 2310], [ 1581, 2310], [ 1582, 2310], [ 1583, 2310], [ 1584, 2310], [ 1585, 2310], [ 1586, 2310], [ 1587, 2310], [ 1588, 2310], [ 1589, 2310], [ 1590, 2310], [ 1591, 2310], [ 1592, 2310], [ 1593, 2310], [ 1594, 2310], [ 1595, 2310], [ 1596, 2310], [ 1597, 2310], [ 1598, 2310], [ 1599, 2310], [ 1600, 2310], [ 1601, 2310], [ 1602, 2310], [ 1603, 2310], [ 1604, 2310], [ 1605, 2310], [ 1606, 2310], [ 1607, 2310], [ 1608, 2310], [ 1609, 2310], [ 1610, 2310], [ 1611, 2310], [ 1612, 2310], [ 1613, 2310], [ 1614, 2310], [ 1615, 2310], [ 1616, 2310], [ 1617, 2310], [ 1618, 2310], [ 1619, 2310], [ 1620, 2310], [ 1621, 2310], [ 1622, 2310], [ 1623, 2310], [ 1624, 2310], [ 1625, 2310], [ 1626, 2310], [ 1627, 2310], [ 1628, 2310], [ 1629, 2310], [ 1630, 2310], [ 1631, 2310], [ 1632, 2310], [ 1633, 2310], [ 1634, 2310], [ 1635, 2310], [ 1636, 2310], [ 1637, 2310], [ 1638, 2310], [ 1639, 2310], [ 1640, 2310], [ 1641, 2310], [ 1642, 2310], [ 1643, 2310], [ 1644, 2310], [ 1645, 2310], [ 1646, 2310], [ 1647, 2310], [ 1648, 2310], [ 1649, 2310], [ 1650, 2310], [ 1651, 2310], [ 1652, 2310], [ 1653, 2310], [ 1654, 2310], [ 1655, 2310], [ 1656, 2310], [ 1657, 2310], [ 1658, 2310], [ 1659, 2310], [ 1660, 2310], [ 1661, 2310], [ 1662, 2310], [ 1663, 2310], [ 1664, 2310], [ 1665, 2310], [ 1666, 2310], [ 1667, 2310], [ 1668, 2310], [ 1669, 2310], [ 1670, 2310], [ 1671, 2310], [ 1672, 2310], [ 1673, 2310], [ 1674, 2310], [ 1675, 2310], [ 1676, 2310], [ 1677, 2310], [ 1678, 2310], [ 1679, 2310], [ 1680, 2310], [ 1681, 2310], [ 1682, 2310], [ 1683, 2310], [ 1684, 2310], [ 1685, 2310], [ 1686, 2310], [ 1687, 2310], [ 1688, 2310], [ 1689, 2310], [ 1690, 2310], [ 1691, 2310], [ 1692, 2310], [ 1693, 2310], [ 1694, 2310], [ 1695, 2310], [ 1696, 2310], [ 1697, 2310], [ 1698, 2310], [ 1699, 2310], [ 1700, 2310], [ 1701, 2310], [ 1702, 2310], [ 1703, 2310], [ 1704, 2310], [ 1705, 2310], [ 1706, 2310], [ 1707, 2310], [ 1708, 2310], [ 1709, 2310], [ 1710, 2310], [ 1711, 2310], [ 1712, 2310], [ 1713, 2310], [ 1714, 2310], [ 1715, 2310], [ 1716, 2310], [ 1717, 2310], [ 1718, 2310], [ 1719, 2310], [ 1720, 2310], [ 1721, 2310], [ 1722, 2310], [ 1723, 2310], [ 1724, 2310], [ 1725, 2310], [ 1726, 2310], [ 1727, 2310], [ 1728, 2310], [ 1729, 2310], [ 1730, 2310], [ 1731, 2310], [ 1732, 2310], [ 1733, 2310], [ 1734, 2310], [ 1735, 2310], [ 1736, 2310], [ 1737, 2310], [ 1738, 2310], [ 1739, 2310], [ 1740, 2310], [ 1741, 2310], [ 1742, 2310], [ 1743, 2310], [ 1744, 2310], [ 1745, 2310], [ 1746, 2310], [ 1747, 2310], [ 1748, 2310], [ 1749, 2310], [ 1750, 2310], [ 1751, 2310], [ 1752, 2310], [ 1753, 2310], [ 1754, 2310], [ 1755, 2310], [ 1756, 2310], [ 1757, 2310], [ 1758, 2310], [ 1759, 2310], [ 1760, 2310], [ 1761, 2310], [ 1762, 2310], [ 1763, 2310], [ 1764, 2310], [ 1765, 2310], [ 1766, 2310], [ 1767, 2310], [ 1768, 2310], [ 1769, 2310], [ 1770, 2310], [ 1771, 2310], [ 1772, 2310], [ 1773, 2310], [ 1774, 2310], [ 1775, 2310], [ 1776, 2310], [ 1777, 2310], [ 1778, 2310], [ 1779, 2310], [ 1780, 2310], [ 1781, 2310], [ 1782, 2310], [ 1783, 2310], [ 1784, 2310], [ 1785, 2310], [ 1786, 2310], [ 1787, 2310], [ 1788, 2310], [ 1789, 2310], [ 1790, 2310], [ 1791, 2310], [ 1792, 2310], [ 1793, 2310], [ 1794, 2310], [ 1795, 2310], [ 1796, 2310], [ 1797, 2310], [ 1798, 2310], [ 1799, 2310], [ 1800, 2310], [ 1801, 2310], [ 1802, 2310], [ 1803, 2310], [ 1804, 2310], [ 1805, 2310], [ 1806, 2310], [ 1807, 2310], [ 1808, 2310], [ 1809, 2310], [ 1810, 2310], [ 1811, 2310], [ 1812, 2310], [ 1813, 2310], [ 1814, 2310], [ 1815, 2310], [ 1816, 2310], [ 1817, 2310], [ 1818, 2310], [ 1819, 2310], [ 1820, 2310], [ 1821, 2310], [ 1822, 2310], [ 1823, 2310], [ 1824, 2310], [ 1825, 2310], [ 1826, 2310], [ 1827, 2310], [ 1828, 2310], [ 1829, 2310], [ 1830, 2310], [ 1831, 2310], [ 1832, 2310], [ 1833, 2310], [ 1834, 2310], [ 1835, 2310], [ 1836, 2310], [ 1837, 2310], [ 1838, 2310], [ 1839, 2310], [ 1840, 2310], [ 1841, 2310], [ 1842, 2310], [ 1843, 2310], [ 1844, 2310], [ 1845, 2310], [ 1846, 2310], [ 1847, 2310], [ 1848, 2310], [ 1849, 2310], [ 1850, 2310], [ 1851, 2310], [ 1852, 2310], [ 1853, 2310], [ 1854, 2310], [ 1855, 2310], [ 1856, 2310], [ 1857, 2310], [ 1858, 2310], [ 1859, 2310], [ 1860, 2310], [ 1861, 2310], [ 1862, 2310], [ 1863, 2310], [ 1864, 2310], [ 1865, 2310], [ 1866, 2310], [ 1867, 2310], [ 1868, 2310], [ 1869, 2310], [ 1870, 2310], [ 1871, 2310], [ 1872, 2310], [ 1873, 2310], [ 1874, 2310], [ 1875, 2310], [ 1876, 2310], [ 1877, 2310], [ 1878, 2310], [ 1879, 2310], [ 1880, 2310], [ 1881, 2310], [ 1882, 2310], [ 1883, 2310], [ 1884, 2310], [ 1885, 2310], [ 1886, 2310], [ 1887, 2310], [ 1888, 2310], [ 1889, 2310], [ 1890, 2310], [ 1891, 2310], [ 1892, 2310], [ 1893, 2310], [ 1894, 2310], [ 1895, 2310], [ 1896, 2310], [ 1897, 2310], [ 1898, 2310], [ 1899, 2310], [ 1900, 2310], [ 1901, 2310], [ 1902, 2310], [ 1903, 2310], [ 1904, 2310], [ 1905, 2310], [ 1906, 2310], [ 1907, 2310], [ 1908, 2310], [ 1909, 2310], [ 1910, 2310], [ 1911, 2310], [ 1912, 2310], [ 1913, 2310], [ 1914, 2310], [ 1915, 2310], [ 1916, 2310], [ 1917, 2310], [ 1918, 2310], [ 1919, 2310], [ 1920, 2310], [ 1921, 2310], [ 1922, 2310], [ 1923, 2310], [ 1924, 2310], [ 1925, 2310], [ 1926, 2310], [ 1927, 2310], [ 1928, 2310], [ 1929, 2310], [ 1930, 2310], [ 1931, 2310], [ 1932, 2310], [ 1933, 2310], [ 1934, 2310], [ 1935, 2310], [ 1936, 2310], [ 1937, 2310], [ 1938, 2310], [ 1939, 2310], [ 1940, 2310], [ 1941, 2310], [ 1942, 2310], [ 1943, 2310], [ 1944, 2310], [ 1945, 2310], [ 1946, 2310], [ 1947, 2310], [ 1948, 2310], [ 1949, 2310], [ 1950, 2310], [ 1951, 2310], [ 1952, 2310], [ 1953, 2310], [ 1954, 2310], [ 1955, 2310], [ 1956, 2310], [ 1957, 2310], [ 1958, 2310], [ 1959, 2310], [ 1960, 2310], [ 1961, 2310], [ 1962, 2310], [ 1963, 2310], [ 1964, 2310], [ 1965, 2310], [ 1966, 2310], [ 1967, 2310], [ 1968, 2310], [ 1969, 2310], [ 1970, 2310], [ 1971, 2310], [ 1972, 2310], [ 1973, 2310], [ 1974, 2310], [ 1975, 2310], [ 1976, 2310], [ 1977, 2310], [ 1978, 2310], [ 1979, 2310], [ 1980, 2310], [ 1981, 2310], [ 1982, 2310], [ 1983, 2310], [ 1984, 2310], [ 1985, 2310], [ 1986, 2310], [ 1987, 2310], [ 1988, 2310], [ 1989, 2310], [ 1990, 2310], [ 1991, 2310], [ 1992, 2310], [ 1993, 2310], [ 1994, 2310], [ 1995, 2310], [ 1996, 2310], [ 1997, 2310], [ 1998, 2310], [ 1999, 2310], [ 2000, 2310], [ 2001, 2310], [ 2002, 2310], [ 2003, 2310], [ 2004, 2310], [ 2005, 2310], [ 2006, 2310], [ 2007, 2310], [ 2008, 2310], [ 2009, 2310], [ 2010, 2310], [ 2011, 2310], [ 2012, 2310], [ 2013, 2310], [ 2014, 2310], [ 2015, 2310], [ 2016, 2310], [ 2017, 2310], [ 2018, 2310], [ 2019, 2310], [ 2020, 2310], [ 2021, 2310], [ 2022, 2310], [ 2023, 2310], [ 2024, 2310], [ 2025, 2310], [ 2026, 2310], [ 2027, 2310], [ 2028, 2310], [ 2029, 2310], [ 2030, 2310], [ 2031, 2310], [ 2032, 2310], [ 2033, 2310], [ 2034, 2310], [ 2035, 2310], [ 2036, 2310], [ 2037, 2310], [ 2038, 2310], [ 2039, 2310], [ 2040, 2310], [ 2041, 2310], [ 2042, 2310], [ 2043, 2310], [ 2044, 2310], [ 2045, 2310], [ 2046, 2310], [ 2047, 2310], [ 2048, 2310], [ 2049, 2310], [ 2050, 2310], [ 2051, 2310], [ 2052, 2310], [ 2053, 2310], [ 2054, 2310], [ 2055, 2310], [ 2056, 2310], [ 2057, 2310], [ 2058, 2310], [ 2059, 2310], [ 2060, 2310], [ 2061, 2310], [ 2062, 2310], [ 2063, 2310], [ 2064, 2310], [ 2065, 2310], [ 2066, 2310], [ 2067, 2310], [ 2068, 2310], [ 2069, 2310], [ 2070, 2310], [ 2071, 2310], [ 2072, 2310], [ 2073, 2310], [ 2074, 2310], [ 2075, 2310], [ 2076, 2310], [ 2077, 2310], [ 2078, 2310], [ 2079, 2310], [ 2080, 2310], [ 2081, 2310], [ 2082, 2310], [ 2083, 2310], [ 2084, 2310], [ 2085, 2310], [ 2086, 2310], [ 2087, 2310], [ 2088, 2310], [ 2089, 2310], [ 2090, 2310], [ 2091, 2310], [ 2092, 2310], [ 2093, 2310], [ 2094, 2310], [ 2095, 2310], [ 2096, 2310], [ 2097, 2310], [ 2098, 2310], [ 2099, 2310], [ 2100, 2310], [ 2101, 2310], [ 2102, 2310], [ 2103, 2310], [ 2104, 2310], [ 2105, 2310], [ 2106, 2310], [ 2107, 2310], [ 2108, 2310], [ 2109, 2310], [ 2110, 2310], [ 2111, 2310], [ 2112, 2310], [ 2113, 2310], [ 2114, 2310], [ 2115, 2310], [ 2116, 2310], [ 2117, 2310], [ 2118, 2310], [ 2119, 2310], [ 2120, 2310], [ 2121, 2310], [ 2122, 2310], [ 2123, 2310], [ 2124, 2310], [ 2125, 2310], [ 2126, 2310], [ 2127, 2310], [ 2128, 2310], [ 2129, 2310], [ 2130, 2310], [ 2131, 2310], [ 2132, 2310], [ 2133, 2310], [ 2134, 2310], [ 2135, 2310], [ 2136, 2310], [ 2137, 2310], [ 2138, 2310], [ 2139, 2310], [ 2140, 2310], [ 2141, 2310], [ 2142, 2310], [ 2143, 2310], [ 2144, 2310], [ 2145, 2310], [ 2146, 2310], [ 2147, 2310], [ 2148, 2310], [ 2149, 2310], [ 2150, 2310], [ 2151, 2310], [ 2152, 2310], [ 2153, 2310], [ 2154, 2310], [ 2155, 2310], [ 2156, 2310], [ 2157, 2310], [ 2158, 2310], [ 2159, 2310], [ 2160, 2310], [ 2161, 2310], [ 2162, 2310], [ 2163, 2310], [ 2164, 2310], [ 2165, 2310], [ 2166, 2310], [ 2167, 2310], [ 2168, 2310], [ 2169, 2310], [ 2170, 2310], [ 2171, 2310], [ 2172, 2310], [ 2173, 2310], [ 2174, 2310], [ 2175, 2310], [ 2176, 2310], [ 2177, 2310], [ 2178, 2310], [ 2179, 2310], [ 2180, 2310], [ 2181, 2310], [ 2182, 2310], [ 2183, 2310], [ 2184, 2310], [ 2185, 2310], [ 2186, 2310], [ 2187, 2310], [ 2188, 2310], [ 2189, 2310], [ 2190, 2310], [ 2191, 2310], [ 2192, 2310], [ 2193, 2310], [ 2194, 2310], [ 2195, 2310], [ 2196, 2310], [ 2197, 2310], [ 2198, 2310], [ 2199, 2310], [ 2200, 2310], [ 2201, 2310], [ 2202, 2310], [ 2203, 2310], [ 2204, 2310], [ 2205, 2310], [ 2206, 2310], [ 2207, 2310], [ 2208, 2310], [ 2209, 2310], [ 2210, 2310], [ 2211, 2310], [ 2212, 2310], [ 2213, 2310], [ 2214, 2310], [ 2215, 2310], [ 2216, 2310], [ 2217, 2310], [ 2218, 2310], [ 2219, 2310], [ 2220, 2310], [ 2221, 2310], [ 2222, 2310], [ 2223, 2310], [ 2224, 2310], [ 2225, 2310], [ 2226, 2310], [ 2227, 2310], [ 2228, 2310], [ 2229, 2310], [ 2230, 2310], [ 2231, 2310], [ 2232, 2310], [ 2233, 2310], [ 2234, 2310], [ 2235, 2310], [ 2236, 2310], [ 2237, 2310], [ 2238, 2310], [ 2239, 2310], [ 2240, 2310], [ 2241, 2310], [ 2242, 2310], [ 2243, 2310], [ 2244, 2310], [ 2245, 2310], [ 2246, 2310], [ 2247, 2310], [ 2248, 2310], [ 2249, 2310], [ 2250, 2310], [ 2251, 2310], [ 2252, 2310], [ 2253, 2310], [ 2254, 2310], [ 2255, 2310], [ 2256, 2310], [ 2257, 2310], [ 2258, 2310], [ 2259, 2310], [ 2260, 2310], [ 2261, 2310], [ 2262, 2310], [ 2263, 2310], [ 2264, 2310], [ 2265, 2310], [ 2266, 2310], [ 2267, 2310], [ 2268, 2310], [ 2269, 2310], [ 2270, 2310], [ 2271, 2310], [ 2272, 2310], [ 2273, 2310], [ 2274, 2310], [ 2275, 2310], [ 2276, 2310], [ 2277, 2310], [ 2278, 2310], [ 2279, 2310], [ 2280, 2310], [ 2281, 2310], [ 2282, 2310], [ 2283, 2310], [ 2284, 2310], [ 2285, 2310], [ 2286, 2310], [ 2287, 2310], [ 2288, 2310], [ 2289, 2310], [ 2290, 2310], [ 2291, 2310], [ 2292, 2310], [ 2293, 2310], [ 2294, 2310], [ 2295, 2310], [ 2296, 2310], [ 2297, 2310], [ 2298, 2310], [ 2299, 2310], [ 2300, 2310], [ 2301, 2310], [ 2302, 2310], [ 2303, 2310], [ 2304, 2310], [ 2305, 2310], [ 2306, 2310], [ 2307, 2310], [ 2308, 2310], [ 2309, 2310]])

# %%
feat_Ca.describe()
# Out:
# ['DIST: MET 65 N 0 - SOD 1 SOD 2310',
#  'DIST: MET 65 CA 1 - SOD 1 SOD 2310',
#  'DIST: MET 65 CB 2 - SOD 1 SOD 2310',
#  'DIST: MET 65 CG 3 - SOD 1 SOD 2310',
#  'DIST: MET 65 SD 4 - SOD 1 SOD 2310',
#  'DIST: MET 65 CE 5 - SOD 1 SOD 2310',
#  'DIST: MET 65 C 6 - SOD 1 SOD 2310',
#  'DIST: MET 65 O 7 - SOD 1 SOD 2310',
#  'DIST: VAL 66 N 8 - SOD 1 SOD 2310',
#  'DIST: VAL 66 CA 9 - SOD 1 SOD 2310',
#  'DIST: VAL 66 CB 10 - SOD 1 SOD 2310',
#  'DIST: VAL 66 CG1 11 - SOD 1 SOD 2310',
#  'DIST: VAL 66 CG2 12 - SOD 1 SOD 2310',
#  'DIST: VAL 66 C 13 - SOD 1 SOD 2310',
#  'DIST: VAL 66 O 14 - SOD 1 SOD 2310',
#  'DIST: THR 67 N 15 - SOD 1 SOD 2310',
#  'DIST: THR 67 CA 16 - SOD 1 SOD 2310',
#  'DIST: THR 67 CB 17 - SOD 1 SOD 2310',
#  'DIST: THR 67 OG1 18 - SOD 1 SOD 2310',
#  'DIST: THR 67 CG2 19 - SOD 1 SOD 2310',
#  'DIST: THR 67 C 20 - SOD 1 SOD 2310',
#  'DIST: THR 67 O 21 - SOD 1 SOD 2310',
#  'DIST: ALA 68 N 22 - SOD 1 SOD 2310',
#  'DIST: ALA 68 CA 23 - SOD 1 SOD 2310',
# ...

# %%
[[i,2310] for i in range(100)]

# %%
inp = coor.source(traj_list, features=feat_Ca)
print('number of trajectories = ',inp.number_of_trajectories())
print('trajectory length = ',inp.trajectory_length(0))

print('number of dimension = ',inp.dimension())
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# ('number of trajectories = ', 159)
# ('trajectory length = ', 6000)
# ('number of dimension = ', 2310)

# %%
len_MD = [inp.trajectory_length(i) for i in range(159)]

# %%
plt.plot(len_MD,marker='o')

# %%
# tica + projection
tica_obj = coor.tica(inp, lag=100, dim=2, kinetic_map=True, stride=20) #project on two dimentions
Y = tica_obj.get_output()
# clustering
cl = coor.cluster_kmeans(data=Y, k=100, stride=10)
# for later use we save the discrete trajectories and cluster center coordinates:
dtrajs = cl.dtrajs
cc_x = cl.clustercenters[:,0]   #projection 1
cc_y = cl.clustercenters[:,1]   #projection 2
# plotting
z,x,y = np.histogram2d(Y[:,0],Y[:,1], bins=50)
F = -np.log(z)
extent = [x[0], x[-1], y[0], y[-1]] #boundary
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# 09-06-17 13:04:22 pyemma.coordinates.clustering.kmeans.KmeansClustering[10] INFO     Cluster centers converged after 7 steps.
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# ...

# %%
# tica + projection
tica_obj = coor.tica(inp, lag=100, dim=2, kinetic_map=True, stride=20) #project on two dimentions
X = tica_obj.get_output()
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"

# %%
## Instantaneous correlation matrix between mean-free input features and TICs
plt.plot(tica_obj.feature_TIC_correlation[:,0])

# %%
plt.plot(tica_obj.feature_TIC_correlation[:,1])

# %%
tica_obj.feature_TIC_correlation
# Out:
# array([[-0.65406168,  0.09197553],
#        [-0.66391396,  0.0862975 ],
#        [-0.65269207,  0.08598196],
#        ...,
#        [-0.54987899, -0.29843605],
#        [-0.5405135 , -0.29514792],
#        [-0.53459943, -0.30175941]])

# %%
correlationtica_obj.feature_TIC_correlation[:,0]
# Out:
# array([-0.65406168, -0.66391396, -0.65269207, ..., -0.54987899,
#        -0.5405135 , -0.53459943])

# %%
distlist=feat_Ca.describe()
distfile=open('dist.txt','w')
for item in distlist:
    distfile.write("%s\n" % item)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-93b497941f68> in <module>()
# ----> 1 dist = 'dist.txt'.read()
#
# AttributeError: 'str' object has no attribute 'read'

# %%
np.savetxt('correlation_TIC',tica_obj.feature_TIC_correlation[:,0])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-e16a0491f684> in <module>()
# ----> 1 dist.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
correlation_dis_TIC[:2310]
# Out:
# array([['DIST: MET 65 N 0 - SOD 1 SOD 2310', '-0.654061680511'],
#        ['DIST: MET 65 CA 1 - SOD 1 SOD 2310', '-0.663913959481'],
#        ['DIST: MET 65 CB 2 - SOD 1 SOD 2310', '-0.652692071451'],
#        ...,
#        ['DIST: CYS 351 C 2307 - SOD 1 SOD 2310', '-0.549878988542'],
#        ['DIST: CYS 351 O 2308 - SOD 1 SOD 2310', '-0.540513497336'],
#        ['DIST: CYS 351 OXT 2309 - SOD 1 SOD 2310', '-0.534599433892']],
#       dtype='|S39')

# %%
np.savetxt('correlation_dis_TIC.dat',correlation_dis_TIC[:2310])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-2466fc211226> in <module>()
# ----> 1 np.savetxt('correlation_dis_TIC.dat',correlation_dis_TIC[:2310])
#
# /sc/orga/projects/filizm02a/general/software/anaconda/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1160                     raise TypeError("Mismatch between array dtype ('%s') and "
#    1161                                     "format specifier ('%s')"
# -> 1162                                     % (str(X.dtype), format))
#    1163         if len(footer) > 0:
#    1164             footer = footer.replace('\n', '\n' + comments)
#
# TypeError: Mismatch between array dtype ('|S39') and format specifier ('%.18e %.18e')

# %%
plt.plot([[X[i][384][0]] for i in range(159)])

# %%
import pickle
pickle.dump(X, open("tica_dist_out.pck","wb"))

# %%
M = pickle.load(open("tica_dist_out.pck","rb"))

# %%
plt.plot([[M[i][384][0]] for i in range(159)])

# %%
cl = coor.cluster_kmeans(data=X, k=200, stride=10, max_iter=100000000)
# for later use we save the discrete trajectories and cluster center coordinates:
dtrajs = cl.dtrajs
cc_x = cl.clustercenters[:,0]   #projection 1
cc_y = cl.clustercenters[:,1]   #projection 2
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# 09-06-17 18:06:51 pyemma.coordinates.clustering.kmeans.KmeansClustering[31] INFO     Cluster centers converged after 9 steps.
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"

# %%
XX = [[X[i][:,0]] for i in range(159)]
YY = [[X[i][:,1]] for i in range(159)]

# %%
XX
# Out:
# [[array([-0.67951697, -0.68073195, -0.7025643 , ..., -0.83455086,
#          -0.83982235, -0.84669256], dtype=float32)],
#  [array([-0.69895017, -0.71305215, -0.72752738, ..., -0.74078983,
#          -0.71954858, -0.73042542], dtype=float32)],
#  [array([-0.69509631, -0.656376  , -0.69162244, ..., -0.80118114,
#          -0.80950516, -0.85245174], dtype=float32)],
#  [array([-0.69598055, -0.70609027, -0.67872149, ..., -0.8292889 ,
#          -0.86803472, -0.85705465], dtype=float32)],
#  [array([-0.68515629, -0.72175074, -0.73868328, ..., -0.65239412,
#          -0.60533142, -0.61013269], dtype=float32)],
#  [array([-0.67120075, -0.66444761, -0.6363278 , ..., -0.85217649,
#          -0.94533741, -0.92735201], dtype=float32)],
#  [array([-0.64299244, -0.59336668, -0.58436948, ..., -0.8179059 ,
#          -0.82215852, -0.82055598], dtype=float32)],
#  [array([-0.63544816, -0.59837902, -0.64267945, ..., -0.86140996,
#          -0.89008796, -0.83730543], dtype=float32)],
# ...

# %%
# plotting
z,x,y = np.histogram2d(X[150][:,0],X[150][:,1], bins=50)
F = -np.log(z)
extent = [x[0], x[-1], y[0], y[-1]] #boundary
# Out:
# /sc/orga/projects/filizm02a/general/software/anaconda/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
plt.contourf(F.T, 50, cmap=plt.cm.hot, extent=extent)
plt.plot(cc_x,cc_y, linewidth=0, marker='o')
plt.xlabel('ind. comp. 1')
plt.ylabel('ind. comp. 2')

# %%
plt.subplot2grid((2, 1), (0, 0))
plt.plot(X[150][:, 0])
plt.ylabel('ind. comp. 1')
plt.subplot2grid((2, 1), (1, 0))
plt.plot(X[150][:, 1])
plt.ylabel('ind. comp. 2')
plt.xlabel('time ( *2 ps)')

# %% [markdown]
# ## MSM estimation

# %%
import pyemma.msm as msm
import pyemma.plots as mplt

# %%
lags = [1,10,50,100,200,400,500,700,1000]
its = msm.its(dtrajs, lags=lags)
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"

# %%
mplt.plot_implied_timescales(its)

# %%
its = msm.its(dtrajs, lags=lags, nits=10, errors='bayes', nsamples=100)
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# ...

# %%
mplt.plot_implied_timescales(its)
plt.ylim(10,1000000)
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %% [markdown]
# ## final MSM

# %%
M = msm.estimate_markov_model(dtrajs, 700)

# %%
plt.plot(M.timescales(),linewidth=0,marker='o')
plt.xlabel('index'); plt.ylabel('timescale (*2ps)'); plt.xlim(-0.5,10.5)
# Out:
# (-0.5, 10.5)

# %%
M.timescales
# Out:
# <bound method MaximumLikelihoodMSM.timescales of MaximumLikelihoodMSM(connectivity='largest', count_mode='sliding',
#            dt_traj='1 step', lag=700, maxerr=1e-08, maxiter=1000000,
#            reversible=True, sparse=False, statdist_constraint=None)>

# %%
plt.plot(M.timescales()[:-1]/M.timescales()[1:], linewidth=0,marker='o')
plt.xlabel('index'); plt.ylabel('timescale separation'); plt.xlim(-0.5,10.5)
# Out:
# (-0.5, 10.5)

# %%
r2
# Out:
# array([ 0.52990401, -1.94941564,  0.53961243,  0.53493637, -1.83378721,
#        -0.32479606, -1.9833257 , -3.09267596,  0.53520087,  0.53276517,
#        -3.12377844,  0.53635102, -3.05731053, -1.8983524 , -1.93462462,
#         0.53807036,  0.50823197,  0.53061578, -1.95924443,  0.53848872,
#         0.53599909, -1.9237943 ,  0.03031407, -0.82204164, -1.96805572,
#         0.53505545, -1.81349792,  0.52993497, -2.85734722, -0.60612845,
#         0.53423498, -3.15453161,  0.43037434,  0.49316738,  0.43265294,
#        -1.9218785 , -1.97231548,  0.5348455 ,  0.53343963,  0.53441986,
#        -3.08927784,  0.47814629, -2.34748987,  0.4833266 , -1.88286027,
#        -0.40863891, -1.78865559, -1.67502912,  0.53780063, -1.9820566 ,
#        -0.73556292,  0.54355053, -2.08676762,  0.5326893 ,  0.53420723,
#        -3.04284711, -2.06354233, -3.1044054 , -1.93325971,  0.50114756,
#         0.11470887,  0.50857349, -1.91361442,  0.54029187, -2.97215265,
# ...

# %%
r2 = M.eigenvectors_right()[:,1]
ax = mplt.scatter_contour(cc_x, cc_y, r2)

# %%
len(r2)
# Out:
# 200

# %%
r3 = M.eigenvectors_right()[:,2]
mplt.scatter_contour(cc_x, cc_y, r3)

# %%
r4 = M.eigenvectors_right()[:,3]
mplt.scatter_contour(cc_x, cc_y, r4)
